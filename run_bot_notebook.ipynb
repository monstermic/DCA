# %%
# %% [markdown]
# # Bybit DCA Bot - Execution Notebook (v9 - Modular)

# %% [markdown]
# **IMPORTANT:**
# 1. Ensure all `.py` files (`config.py`, `state_manager.py`, `utils.py`, `bybit_client.py`, `indicators.py`, `order_manager.py`, `position_manager.py`, `main_logic.py`) are in the same directory as this notebook.
# 2. Make sure required libraries are installed (`pip install pybit pandas pandas_ta python-dotenv`).
# 3. Set your Bybit Testnet API keys as environment variables OR create a `.env` file in this directory and ensure `config.py` is set up to load it.

# %%
# --- Imports ---
import time
import config         # To access parameters if needed directly (usually not needed here)
import state_manager
import bybit_client
import main_logic     # Imports the core bot cycle logic

# --- Control ---
# How often to run the main logic cycle (in seconds) when looping
# Set to 0 if you want to run cycles purely manually by re-running the execution cell
RUN_INTERVAL_SECONDS = 5

# %% [markdown]
# ## 1. Initialize Session, Load State, Fetch Symbol Info
# Run this cell ONCE when starting or restarting the notebook kernel. Check output for errors.

# %%
# --- Initial Load State FIRST ---
# Load previous state before initializing (though init resets some state if no position)
bot_state = state_manager.load_state()

# --- Initialize Session and Get Symbol Info ---
print("--- Attempting Initialization ---")
session = None      # Will be populated by successful initialization
symbol_info = None  # Will be populated by successful initialization
initialized_ok = False # Flag to track success

# Call the main initialization function from bybit_client
# It returns True/False for success, and the symbol_info dict on success
init_success, fetched_symbol_info = bybit_client.initialize_session_and_config()

if init_success:
    print("--- Initialization SUCCESSFUL ---")
    session = bybit_client.get_session() # Get the successfully created session
    symbol_info = fetched_symbol_info  # Store the fetched symbol info
    initialized_ok = True
    # Optional: Reload state again AFTER successful init if needed?
    # bot_state = state_manager.load_state() # Usually load at start is fine
else:
    print("--- Initialization FAILED ---")
    # Session will remain None, bot cannot run

# --- Final Check ---
if not session or not symbol_info:
     print("CRITICAL: Session or Symbol Info is missing after initialization attempt. Bot cannot run.")
     initialized_ok = False
else:
     # Ensure bot_state exists even if file load failed but init worked
     if not bot_state:
         bot_state = state_manager.load_state() # Try loading again or use initial
     print("Ready to run bot cycle.")
     # Display initial state loaded/set
     print(f"Initial Bot State: {bot_state}")


# %% [markdown]
# ## 2. Run Bot Cycle(s)
# Execute the cell below.
# - If `RUN_INTERVAL_SECONDS > 0` (set in first cell), it will loop indefinitely (Press Kernel -> Interrupt to stop).
# - If `RUN_INTERVAL_SECONDS = 0`, it will run only ONE cycle each time you execute it.

# %%
if initialized_ok:
    if RUN_INTERVAL_SECONDS > 0:
        print(f"Starting continuous loop (checking every {RUN_INTERVAL_SECONDS} seconds)... Press Kernel -> Interrupt to stop.")
        try:
            while True:
                # --- Execute One Cycle ---
                # Pass the current state and get the potentially modified state back
                bot_state = main_logic.run_bot_cycle(session, bot_state, symbol_info)

                print(f"Loop finished. Waiting {RUN_INTERVAL_SECONDS} seconds...")
                time.sleep(RUN_INTERVAL_SECONDS)
        except KeyboardInterrupt:
            print("\nLoop interrupted by user. Saving final state...")
            state_manager.save_state(bot_state) # Save state on interrupt
            print("State saved. Exiting loop.")
        except Exception as e:
            print(f"!!! UNHANDLED ERROR in main loop: {e}")
            print("Saving state before potentially stopping...")
            state_manager.save_state(bot_state)
            # Depending on error, might want to break or continue after delay
            print(f"Loop stopped due to error.")
    else:
        # --- Execute One Cycle Manually ---
        print("Running a single bot cycle...")
        # Pass the current state and get the potentially modified state back
        bot_state = main_logic.run_bot_cycle(session, bot_state, symbol_info)
        print("Single cycle complete. Run this cell again for next cycle.")
        # State is saved within run_bot_cycle when changes occur
else:
    print("Bot cannot run because session or symbol info failed to initialize in the previous cell.")

# %% [markdown]
# ## 3. (Optional) Manual State Save
# You can run this cell to manually save the current state if needed. State is also saved automatically during the cycle when changes happen (like SO placement or resets).

# %%
# if 'bot_state' in locals() and bot_state and initialized_ok:
#     print("Manually saving state...")
#     state_manager.save_state(bot_state)
#     print("State saved.")
# elif not initialized_ok:
#     print("Cannot save state, initialization failed.")
# else:
#     print("Bot state not available to save (run initialization first).")
# Out:
# INFO: Using estimated total fee buffer for TP: 0.1100%
# State loaded from bot_state_3m.json
# --- Attempting Initialization ---
# Attempting to initialize Bybit HTTP session...
# Bybit session initialized and API keys seem valid.
# Attempting to set leverage for BTCUSDT to 10x...
# Warning: Error during leverage setting: leverage not modified (ErrCode: 110043) (ErrTime: 06:26:06).
# Request → POST https://api-testnet.bybit.com/v5/position/set-leverage: {"category": "linear", "symbol": "BTCUSDT", "buyLeverage": "10", "sellLeverage": "10"}.
# Fetching Instrument Info...
# Symbol Info OK: PPrec=2, QPrec=3, MinQ=0.001, MaxQ=1190.0, Step=0.001
# --- Initialization SUCCESSFUL ---
# Ready to run bot cycle.
# Initial Bot State: {'filled_safety_orders_count': 0, 'calculated_base_qty_this_cycle': 0.001, 'active_safety_order_ids': [], 'is_in_trade': True, 'current_trade_entry_timestamp': 1745277875540, 'current_trade_side': 'Sell', 'current_trade_avg_price': 79800.0, 'pending_entry_order_id': None, 'pending_order_placed_timestamp': 0, 'tsl_activated_this_trade': False}
# Starting continuous loop (checking every 5 seconds)... Press Kernel -> Interrupt to stop.
#
# ----- 2025-04-22 14:26:06 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=True, PendingEntry=None, PlacedTime=0, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
#
# --- Position Closed! Logging Journal Entry & Resetting State ---
# --- Trade Logged to trade_journal.csv ---
#    Trade state reset.
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:26:11 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=None, PlacedTime=0, FilledSOs=0, BaseQty=0.0, ActiveSOs=0, TSLActive=False
# No active position or pending entry. Checking trend & sizing...
#
# Fetching kline (3) for bias...
# SMAs: F=77378.02, S=77404.62 | RSI=58.49
# Bias Signal: Bearish (Fast < Slow)
# Bias: Sell. Calculating size & checking margin...
# Equity:22.8836, Mark:77667.73, Risk:$0.1144, SLDist:$310.67, RawQty:0.000368
# Target Qty: 0.001
#    Est Val:$77.67 | Need Margin(10.0x):$7.7668 | Avail:$21.7394
#    Sufficient margin.
# Placing LIMIT base order @ price: 77667.73
# --- Placing BASE Limit Order ---
#    BTCUSDT, Sell, Qty: 0.001, Limit Price: 77667.73
#    API Resp: {"retCode": 0, "retMsg": "OK", "result": {"orderId": "f9276e76-8bc3-4231-83c4-5b374e39cda5", "orderLinkId": ""}, "retExtInfo": {}, "time": 1745303172348}
#    >>> Success! Limit Order Placed ID: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Base limit order f9276e76-8bc3-4231-83c4-5b374e39cda5 placed. State set to pending...
# ----- Check Cycle Complete -----
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:26:17 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 5s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:26:22 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 10s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:26:27 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 16s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:26:33 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 21s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:26:38 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 26s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:26:43 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 31s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:26:48 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 36s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:26:53 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 42s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:26:59 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 47s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:27:04 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 52s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:27:09 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 57s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:27:14 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 63s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:27:20 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 68s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:27:25 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Warning: Order ID f9276e76-8bc3-4231-83c4-5b374e39cda5 not found in recent history.
#    Checked Open Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = New
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'New'
#    Base order f9276e76-8bc3-4231-83c4-5b374e39cda5 still New. Elapsed: 73s / Timeout: 180s
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:27:30 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=False, PendingEntry=f9276e76-8bc3-4231-83c4-5b374e39cda5, PlacedTime=1745303172, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Checking status of pending entry order: f9276e76-8bc3-4231-83c4-5b374e39cda5
#    Checked Order f9276e76-8bc3-4231-83c4-5b374e39cda5: Status = Filled
# DEBUG Main: Status returned for f9276e76-8bc3-4231-83c4-5b374e39cda5: 'Filled'
#    >>> Base Order f9276e76-8bc3-4231-83c4-5b374e39cda5 Filled! Entering trade state.
# Pos Found: Side=Sell, Size=0.001, Entry=77667.8, Liq=85046.2
#    DEBUG Main: Pos fetched. AvgP=77667.8, Side=Sell. Calc TP/SL...
#    DEBUG Main: Calc TP=77038.69, SL=77978.47. Setting...
# --- Setting/Updating TP/SL ---
#    Sending Params: {'category': 'linear', 'symbol': 'BTCUSDT', 'tpslMode': 'Full', 'takeProfit': '77038.69', 'stopLoss': '77978.47'}
#    API Resp: {"retCode": 0, "retMsg": "OK", "result": {}, "retExtInfo": {}, "time": 1745303250961}
#    >>> Success.
#    DEBUG Main: TP/SL set OK.
#    DEBUG Main: State saved.
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:27:35 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=True, PendingEntry=None, PlacedTime=0, FilledSOs=0, BaseQty=0.001, ActiveSOs=0, TSLActive=False
# Pos Found: Side=Sell, Size=0.001, Entry=77667.8, Liq=85046.2
#
# Position found (Side: Sell). Checking for safety order...
# Mark Price: 77800.0
#    Checking for SO #1 using Step: 0.15%
#    Calculated SO Trigger Price: 77784.30
#
# !!! SO TRIGGERED !!! (Filled Count: 0)
# --- Placing Safety Order ---
#    Checking SO vs Liq Danger (1.0%): SO Price=77784.30, Danger Price=84195.74
#    Safety check PASSED.
#    BTCUSDT, Sell, Qty: 0.001, Price: 77784.30
#    API Resp: {"retCode": 0, "retMsg": "OK", "result": {"orderId": "4fa5b4ae-002a-4c9e-b0da-ba5f3702f6fc", "orderLinkId": ""}, "retExtInfo": {}, "time": 1745303256323}
#    >>> Success! SO ID: 4fa5b4ae-002a-4c9e-b0da-ba5f3702f6fc
#    Added 4fa5b4ae-002a-4c9e-b0da-ba5f3702f6fc to active SO list.
# ----- Check Cycle Complete -----
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:27:41 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=True, PendingEntry=None, PlacedTime=0, FilledSOs=0, BaseQty=0.001, ActiveSOs=1, TSLActive=False
#
# Checking status of 1 active SO ID(s): ['4fa5b4ae-002a-4c9e-b0da-ba5f3702f6fc']
# Pos Found: Side=Sell, Size=0.001, Entry=77667.8, Liq=85046.2
#
# Position found (Side: Sell). Checking for safety order...
# Mark Price: 77800.0
#    Checking for SO #1 using Step: 0.15%
#    Calculated SO Trigger Price: 77784.30
#
# !!! SO TRIGGERED !!! (Filled Count: 0)
# --- Placing Safety Order ---
#    Checking SO vs Liq Danger (1.0%): SO Price=77784.30, Danger Price=84195.74
#    Safety check PASSED.
#    BTCUSDT, Sell, Qty: 0.001, Price: 77784.30
#    !!! Error placing SO: ab not enough for new order (ErrCode: 110007) (ErrTime: 06:27:41).
# Request → POST https://api-testnet.bybit.com/v5/order/create: {"category": "linear", "symbol": "BTCUSDT", "side": "Sell", "orderType": "Limit", "qty": "0.001", "price": "77784.30", "timeInForce": "GTC"}.
# ----- Check Cycle Complete -----
# Loop finished. Waiting 5 seconds...
#
# ----- 2025-04-22 14:27:46 Running Check -----
# State loaded from bot_state_3m.json
# State: InTrade=True, PendingEntry=None, PlacedTime=0, FilledSOs=0, BaseQty=0.001, ActiveSOs=1, TSLActive=False
#
# Checking status of 1 active SO ID(s): ['4fa5b4ae-002a-4c9e-b0da-ba5f3702f6fc']
# Pos Found: Side=Sell, Size=0.001, Entry=77667.8, Liq=85046.2
#
# Position found (Side: Sell). Checking for safety order...
# Mark Price: 77800.0
#    Checking for SO #1 using Step: 0.15%
#    Calculated SO Trigger Price: 77784.30
#
# !!! SO TRIGGERED !!! (Filled Count: 0)
# --- Placing Safety Order ---
#    Checking SO vs Liq Danger (1.0%): SO Price=77784.30, Danger Price=84195.74
#    Safety check PASSED.
#    BTCUSDT, Sell, Qty: 0.001, Price: 77784.30
#    !!! Error placing SO: ab not enough for new order (ErrCode: 110007) (ErrTime: 06:27:47).
# Request → POST https://api-testnet.bybit.com/v5/order/create: {"category": "linear", "symbol": "BTCUSDT", "side": "Sell", "orderType": "Limit", "qty": "0.001", "price": "77784.30", "timeInForce": "GTC"}.
# ----- Check Cycle Complete -----
# Loop finished. Waiting 5 seconds...
